# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting xgboost==3.0.2
#   Downloading xgboost-3.0.2-py3-none-manylinux_2_28_x86_64.whl (253.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━ 253.9/253.9 MB 3.3 MB/s eta 0:00:00
# Collecting shap==0.48.0
#   Downloading shap-0.48.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (996 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 996.4/996.4 kB 67.6 MB/s eta 0:00:00
# Collecting statsmodels
#   Downloading statsmodels-0.14.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━ 10.7/10.7 MB 103.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /root/venv/lib/python3.10/site-packages (from xgboost==3.0.2->-r ./requirements.txt (line 2)) (1.25.2)
# Requirement already satisfied: scipy in /root/venv/lib/python3.10/site-packages (from xgboost==3.0.2->-r ./requirements.txt (line 2)) (1.9.3)
# Collecting nvidia-nccl-cu12
#   Downloading nvidia_nccl_cu12-2.27.7-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━ 322.5/322.5 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /root/venv/lib/python3.10/site-packages (from shap==0.48.0->-r ./requirements.txt (line 3)) (4.14.1)
# Requirement already satisfied: pandas in /root/venv/lib/python3.10/site-packages (from shap==0.48.0->-r ./requirements.txt (line 3)) (2.1.4)
# Requirement already satisfied: scikit-learn in /root/venv/lib/python3.10/site-packages (from shap==0.48.0->-r ./requirements.txt (line 3)) (1.1.3)
# Collecting slicer==0.0.8
#   Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Requirement already satisfied: cloudpickle in /root/venv/lib/python3.10/site-packages (from shap==0.48.0->-r ./requirements.txt (line 3)) (2.2.1)
# Collecting numba>=0.54
#   Downloading numba-0.61.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 3.8/3.8 MB 103.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>20.9 in /root/venv/lib/python3.10/site-packages (from shap==0.48.0->-r ./requirements.txt (line 3)) (25.0)
# Requirement already satisfied: tqdm>=4.27.0 in /root/venv/lib/python3.10/site-packages (from shap==0.48.0->-r ./requirements.txt (line 3)) (4.67.1)
# Collecting patsy>=0.5.6
#   Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 232.9/232.9 kB 23.8 MB/s eta 0:00:00
# Collecting llvmlite<0.45,>=0.44.0dev0
#   Downloading llvmlite-0.44.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 42.4/42.4 MB 36.2 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.10/site-packages (from pandas->shap==0.48.0->-r ./requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.10/site-packages (from pandas->shap==0.48.0->-r ./requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.10/site-packages (from pandas->shap==0.48.0->-r ./requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: joblib>=1.0.0 in /root/venv/lib/python3.10/site-packages (from scikit-learn->shap==0.48.0->-r ./requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /root/venv/lib/python3.10/site-packages (from scikit-learn->shap==0.48.0->-r ./requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->shap==0.48.0->-r ./requirements.txt (line 3)) (1.17.0)
# Installing collected packages: slicer, patsy, nvidia-nccl-cu12, llvmlite, xgboost, numba, statsmodels, shap
# Successfully installed llvmlite-0.44.0 numba-0.61.2 nvidia-nccl-cu12-2.27.7 patsy-1.0.1 shap-0.48.0 slicer-0.0.8 statsmodels-0.14.5 xgboost-3.0.2
#
# [notice] A new release of pip is available: 23.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
